# %% [markdown]
# <a href="https://colab.research.google.com/github/berfino/pandas_examples/blob/main/Pandas01_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###1) İndexlerinde "Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men"  , "Captain America"  , "Disaster Movie" olan Datasında 9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1 olan bir seri oluşturun.(2 Farklı yolla da oluşturun) (Datayı ve İndexleri liste olarak göndererek ve doğrudan dictionary göndererek.)

# %%
index = ["Breaking Bad" , "Chernobyl" , "Leyla ile Mecnun" , "X-Men" , "Captain America" , "Disaster Movie" ]
data = [ 9.4 , 9.3 , 8.8 , 8.4 , 3.8 , 2.1]

# %%
series = pd.Series(data,index)
series
# Out:
# Breaking Bad        9.4
# Chernobyl           9.3
# Leyla ile Mecnun    8.8
# X-Men               8.4
# Captain America     3.8
# Disaster Movie      2.1
# dtype: float64

# %%
dictionary = {
    "Breaking Bad" : 9.4,
    "Chernobyl": 9.3,
    "Leyla ile Mecnun" : 8.8,
    "X-Men" : 8.4,
    "Captain America" : 3.8,
    "Disaster Movie" : 2.1
}
dictionary
# Out:
# {'Breaking Bad': 9.4,
#  'Chernobyl': 9.3,
#  'Leyla ile Mecnun': 8.8,
#  'X-Men': 8.4,
#  'Captain America': 3.8,
#  'Disaster Movie': 2.1}

# %% [markdown]
# ### 2) donem1_mat adında bir seri oluşturun. Bu serinin içinde "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" index değerleri olsun, 85, 80 , 94 , 74 , 91 , 96 , 70 data değerleri olsun. Bu şekilde donem1 adında öğrencilerin 1.dönem matematik nor ortalamalarının tutulduğu bir seri oluşturun. donem2_mat adında başka bir seri oluşturun. Okula yeni bir öğrenci gelmiş olsun ve indexlerde bu sefer "Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" ,"Mert"         indexleri olsun. 80, 92 , 85 , 87, 90 , 92, 100, 83 ise dataları olsun. Bu iki seriyi birleştirerek bütün öğrencilerin yıl sonu matematik ORTALAMASINI hesaplayın.
#
#    ##Not : Eğer bir öğrencinin sadece ikinci dönem notu bulunuyorsa, birinci dönem hesaba eklenmeden ikinci dönem notu yıl sonu notu olarak hesaplansın.

# %%
donem1_mat = pd.Series( [85, 80 , 94 , 74 , 91 , 96 , 70],
                       index = ["Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya"])
donem1_mat
# Out:
# Ali        85
# Deniz      80
# Aslı       94
# Burak      74
# Kerem      91
# Yasemin    96
# Derya      70
# dtype: int64

# %% [markdown]
# ##

# %%
donem2_mat = pd.Series( [80, 92 , 85 , 87, 90 , 92, 100, 83],
                       index = ["Ali" ,"Deniz" ,"Aslı" ,"Burak" ,"Kerem" ,"Yasemin" ,"Derya" ,"Mert"])
donem2_mat
# Out:
# Ali         80
# Deniz       92
# Aslı        85
# Burak       87
# Kerem       90
# Yasemin     92
# Derya      100
# Mert        83
# dtype: int64

# %%
donem_mat = pd.concat([donem1_mat, donem2_mat]).groupby(level=0).mean() # level = 0 --> sadece indexleri grupladığımız belirtmek için kullanılmıştır. 
donem_mat
# Out:
# Ali        82.5
# Aslı       89.5
# Burak      80.5
# Deniz      86.0
# Derya      85.0
# Kerem      90.5
# Mert       83.0
# Yasemin    94.0
# dtype: float64

# %% [markdown]
# ### İndexlerinde "Osman", "Ozlem", "İnci", "Koray", "Melek" olan, columnlarında "Sınıf" , "Cinsiyet" , "Favori Ders" isimlerinde 3 column bulunan bir DF oluşturacaksınız. Osman'ın sınıfı 8 , cinsiyeti "E" , Favori Dersi "Fen",Ozlem'in sınıfı 11 , cinsiyeti "K" , Favori Dersi "Mat", İnci'nin sınıfı 5 , cinsiyeti "K" , Favori Dersi "Sosyal",Koray'ın sınıfı 9 , cinsiyeti "E" , Favori Dersi "Mat",Meleğin sınıfı 7 , cinsiyeti "K" , Favori Dersi "Ing" Olacak şekilde bir df oluşturun.

# %%
data = {'Öğrenci': ['Osman', 'Ozlem', 'İnci', 'Koray', 'Melek'],
        'Sınıf': [8, 11, 5, 9, 7],
        'Cinsiyet': ['E', 'K', 'K', 'E', 'K'],
        'Favori Ders': ['Fen', 'Mat', 'Sosyal', 'Mat', 'Ing']}

df = pd.DataFrame(data)
df = df.set_index('Öğrenci')
df
# Out:
#          Sınıf Cinsiyet Favori Ders
# Öğrenci
# Osman        8        E         Fen
# Ozlem       11        K         Mat
# İnci         5        K      Sosyal
# Koray        9        E         Mat
# Melek        7        K         Ing

# %% [markdown]
# ###4) GitHubda bulunan "Advertising.csv" reklam datasını herhangi bir platformda DF olarak okuyun ve "df_adv" adında bir değişkene atayın. Ardından df_adv değişkeninin ilk 3 satırına, son 3 satırına , rastgele 3 satırına bakın.

# %%
df_adv = pd.read_csv('Advertising.csv')
df_adv
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df_adv.head(3)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3

# %%
df_adv.tail(3)
# Out:
#         TV  radio  newspaper  sales
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df_adv.sample(3)
# Out:
#         TV  radio  newspaper  sales
# 75    16.9   43.7       89.4    8.7
# 180  156.6    2.6        8.3   10.5
# 80    76.4   26.7       22.3   11.8

# %% [markdown]
# ###  Elde ettiğiniz "df_adv" infosuna ve describe'ına bakın ve yorumlamaya çalışın.

# %%
df_adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df_adv.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ### df_adv içinden sadece "TV" sütununu seri olarak çekin.

# %%
df_adv[['TV']]
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %% [markdown]
# ### df_adv içinden "TV" ve "sales" sütununu çekin ve df_salesTV adında bir değişkene atayın.

# %%
df_salesTV = df_adv[['TV','sales']]
df_salesTV
# Out:
#         TV  sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %% [markdown]
# ### df_adv içindeki "TV" , "radio" , "newspaper" sütunlarındaki değerleri toplayarak "total_adv" adında yeni bir sütun oluşturun.

# %%
df_adv['total_adv'] = df_adv['TV'] + df_adv['radio'] + df_adv['newspaper']
df_adv
# Out:
#         TV  radio  newspaper  sales  total_adv
# 0    230.1   37.8       69.2   22.1      337.1
# 1     44.5   39.3       45.1   10.4      128.9
# 2     17.2   45.9       69.3    9.3      132.4
# 3    151.5   41.3       58.5   18.5      251.3
# 4    180.8   10.8       58.4   12.9      250.0
# ..     ...    ...        ...    ...        ...
# 195   38.2    3.7       13.8    7.6       55.7
# 196   94.2    4.9        8.1    9.7      107.2
# 197  177.0    9.3        6.4   12.8      192.7
# 198  283.6   42.0       66.2   25.5      391.8
# 199  232.1    8.6        8.7   13.4      249.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ### df_adv içindeki "sales" sütununun drop edilmiş halini ekrana yazdırın. (Kalıcı hale getirmeyin. Sadece ekrana bastırın)

# %%
df_adv.drop('sales',axis=1)
# Out:
#         TV  radio  newspaper  total_adv
# 0    230.1   37.8       69.2      337.1
# 1     44.5   39.3       45.1      128.9
# 2     17.2   45.9       69.3      132.4
# 3    151.5   41.3       58.5      251.3
# 4    180.8   10.8       58.4      250.0
# ..     ...    ...        ...        ...
# 195   38.2    3.7       13.8       55.7
# 196   94.2    4.9        8.1      107.2
# 197  177.0    9.3        6.4      192.7
# 198  283.6   42.0       66.2      391.8
# 199  232.1    8.6        8.7      249.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ### df_adv içindeki son 50 index'i(satırı) çekin ve ekrana yazdırın.

# %%
df_adv.tail(50)
# Out:
#         TV  radio  newspaper  sales  total_adv
# 150  280.7   13.9       37.0   16.1      331.6
# 151  121.0    8.4       48.7   11.6      178.1
# 152  197.6   23.3       14.2   16.6      235.1
# 153  171.3   39.7       37.7   19.0      248.7
# 154  187.8   21.1        9.5   15.6      218.4
# 155    4.1   11.6        5.7    3.2       21.4
# 156   93.9   43.5       50.5   15.3      187.9
# 157  149.8    1.3       24.3   10.1      175.4
# 158   11.7   36.9       45.2    7.3       93.8
# 159  131.7   18.4       34.6   12.9      184.7
# 160  172.5   18.1       30.7   14.4      221.3
# 161   85.7   35.8       49.3   13.3      170.8
# 162  188.4   18.1       25.6   14.9      232.1
# 163  163.5   36.8        7.4   18.0      207.7
# 164  117.2   14.7        5.4   11.9      137.3
# 165  234.5    3.4       84.8   11.9      322.7
# 166   17.9   37.6       21.6    8.0       77.1
# 167  206.8    5.2       19.4   12.2      231.4
# 168  215.4   23.6       57.6   17.1      296.6
# ...

# %% [markdown]
# ### df_adv içinde satışları 25'den fazla olanları getirin.

# %%
df_adv[df_adv['sales']>25]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 36   266.9   43.8        5.0   25.4      315.7
# 98   289.7   42.3       51.2   25.4      383.2
# 147  243.2   49.0       44.3   25.4      336.5
# 175  276.9   48.9       41.8   27.0      367.6
# 183  287.6   43.0       71.8   26.2      402.4
# 198  283.6   42.0       66.2   25.5      391.8

# %% [markdown]
# ### df_adv içinde "TV" reklamlarına 250'den fazla VE "newspaper" reklamlarına 60'dan fazla harcama yapanları getirin.

# %%
df_adv[(df_adv['TV']>250) & (df_adv['newspaper']>60 )]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 93   250.9   36.5       72.3   22.2      359.7
# 101  296.4   36.3      100.9   23.8      433.6
# 183  287.6   43.0       71.8   26.2      402.4
# 198  283.6   42.0       66.2   25.5      391.8

# %% [markdown]
# ### df_adv içinde "newspaper" reklam harcamaları 70'den fazla VEYA "radio" reklam harcamaları 50'den fazla olanları getirin.

# %%
df_adv[(df_adv['newspaper']>70) | (df_adv['radio']>50 )]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 5      8.7   48.9       75.0    7.2      132.6
# 16    67.8   36.6      114.0   12.5      218.4
# 75    16.9   43.7       89.4    8.7      150.0
# 88    88.3   25.5       73.4   12.9      187.2
# 93   250.9   36.5       72.3   22.2      359.7
# 101  296.4   36.3      100.9   23.8      433.6
# 118  125.7   36.9       79.2   15.9      241.8
# 124  229.5   32.3       74.2   19.7      336.0
# 141  193.7   35.4       75.6   19.2      304.7
# 165  234.5    3.4       84.8   11.9      322.7
# 183  287.6   43.0       71.8   26.2      402.4

# %% [markdown]
# ###  df_adv içinde "sales" ları 10 ile 15(10 ve 15 dahil) arasında olanları getirin.

# %%
df_adv[df_adv['sales'].between(10,16)]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 1     44.5   39.3       45.1   10.4      128.9
# 4    180.8   10.8       58.4   12.9      250.0
# 6     57.5   32.8       23.5   11.8      113.8
# 7    120.2   19.6       11.6   13.2      151.4
# 9    199.8    2.6       21.2   10.6      223.6
# ..     ...    ...        ...    ...        ...
# 186  139.5    2.1       26.6   10.3      168.2
# 188  286.0   13.9        3.7   15.9      303.6
# 190   39.5   41.1        5.8   10.8       86.4
# 197  177.0    9.3        6.4   12.8      192.7
# 199  232.1    8.6        8.7   13.4      249.4
#
# [93 rows x 5 columns]

# %% [markdown]
# ### df_adv içinde "sales" ları tam olarak 18.3 veya 14.0 veya 25.5 veya 21.7 veya 13.6 veya 6.9 olanları getirin.

# %%
df_adv[(df_adv['sales'] == 18.3) | (df_adv['sales'] == 14.0) | (df_adv['sales'] == 25.5) | (df_adv['sales'] == 21.7) | (df_adv['sales'] == 6.9)]
# Out:
#         TV  radio  newspaper  sales  total_adv
# 63   102.7   29.6        8.4   14.0      140.7
# 70   199.1   30.6       38.7   18.3      268.4
# 76    27.5    1.6       20.7    6.9       49.8
# 84   213.5   43.0       33.8   21.7      290.3
# 198  283.6   42.0       66.2   25.5      391.8

# %% [markdown]
# ### GitHubda bulunan "tips.csv" restoran datasını "df_tips" adıyla okuyun. Ardından ilk 5 satırına bakın.

# %%
df_tips = pd.read_csv('tips.csv')
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# ###  df_tips'in "CC Number" ve "Payment ID" column'larını kalıcı olarak düşürün.

# %%
df_tips.drop('CC Number', axis= 1, inplace = True)
df_tips.drop('Payment ID', axis=1, inplace = True) ## düşürüp tekrar çalıştırdığım için hata verdi.

# %%
df_tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name
# 0  Christy Cunningham
# 1      Douglas Tucker
# 2      Travis Walters

# %% [markdown]
# ### df_tips'in "Payer Name" column'unu kalıcı olarak index yapın ve artık columndan düşürün.

# %%
df_tips.set_index('Payer Name',drop = True, inplace = True)

# %%
df_tips
# Out:
#                     total_bill   tip     sex smoker   day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No   Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No   Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No   Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No   Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No   Sun  Dinner     4
# ...                        ...   ...     ...    ...   ...     ...   ...
# Michael Avila            29.03  5.92    Male     No   Sat  Dinner     3
# Monica Sanders           27.18  2.00  Female    Yes   Sat  Dinner     2
# Keith Wong               22.67  2.00    Male    Yes   Sat  Dinner     2
# Dennis Dixon             17.82  1.75    Male     No   Sat  Dinner     2
# Michelle Hardin          18.78  3.00  Female     No  Thur  Dinner     2
#
#                     price_per_person
# Payer Name
# Christy Cunningham              8.49
# ...

# %% [markdown]
# ### df_tips içindeki kayıtlardan kişi sayısı 4 veya 4'den fazla olan siparişlerin kaç tane olduğunu bulun.(Sorguyu yazıp istediğimiz satırları getirdikten sonra basitçe len() fonksiyonunu kullanarak sayılarını bulabilirsiniz. Veya daha güzeli .shape[0] yaparak elde ettiğiniz sorguda kaç satır olduğunun sayısına ulaşabilirsiniz.)

# %%
df_tips
# Out:
#                     total_bill   tip     sex smoker   day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No   Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No   Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No   Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No   Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No   Sun  Dinner     4
# ...                        ...   ...     ...    ...   ...     ...   ...
# Michael Avila            29.03  5.92    Male     No   Sat  Dinner     3
# Monica Sanders           27.18  2.00  Female    Yes   Sat  Dinner     2
# Keith Wong               22.67  2.00    Male    Yes   Sat  Dinner     2
# Dennis Dixon             17.82  1.75    Male     No   Sat  Dinner     2
# Michelle Hardin          18.78  3.00  Female     No  Thur  Dinner     2
#
#                     price_per_person
# Payer Name
# Christy Cunningham              8.49
# ...
